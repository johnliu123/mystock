# %%
from pymongo import MongoClient
import pymongo
import urllib.parse
from datetime import datetime

# %%
#使用python 3.4版本
client=MongoClient("mongodb://john:aaa0936877093@cluster0-shard-00-00.mzxac.mongodb.net:27017,cluster0-shard-00-01.mzxac.mongodb.net:27017,cluster0-shard-00-02.mzxac.mongodb.net:27017/stock?ssl=true&replicaSet=atlas-rumnf9-shard-0&authSource=admin&retryWrites=true&w=majority")

# %%
db = client["stock"]
collection_name = 'mystock'
coll = db[collection_name]

# %%
#####取出所有doc #####
coll.find()

# %%
#將collection的值轉成list
list(coll.find())
# Out:
# [{'_id': ObjectId('5fe4a4093aa9f68e831f8c91'), 'username': 'banana'},
#  {'_id': ObjectId('5fe4a40f3aa9f68e831f8c92'), 'username': 'banana'}]

# %%
##### 插入 單行 #####
dic = {'username':'banana',}

coll.insert_one(dic)

# %%
for document in coll.find():
    # do stuff with document
    print(document)
# Out:
# {'_id': ObjectId('5fe447f980ce98ff41dff474'), 'username': 'apple'}
# {'_id': ObjectId('5fe4a32f3aa9f68e831f8c90'), 'username': 'banana'}
